# %% [markdown]
# ![PIC UPV PERTE Chip Chair Logo](https://www.pic-chair.upv.es/wp-content/uploads/2024/05/logo-upv-horizontal.png)
# ![PIC UPV PERTE Chip Chair Logo](https://www.pic-chair.upv.es/wp-content/uploads/2024/06/logos-perte-chip-1024x119.png)
#
#
# # Laboratory 1. Waveguides

# %% [markdown]
# Welcome to our Photonic Integrated Circuits Laboratory! Throughout the course, we will be using a Python package called [GDSFactory](https://gdsfactory.github.io/gdsfactory/index.html). This is an open-source tool, and is a great alternative to other commercial software like Synopsys Optodesigner, Luceda Photonics, or Lumerical/Interconnect. Since it runs on Python, you have two options for executing your laboratory tasks:
#
# 1. **Local installation on your own PC** (Recommended): Please note that we will not spend class time on installing the software. However, feel free to reach out if you need help with the installation.
#
# 2. **Cloud Workspace**: Alternatively, you can use a cloud-based solution if the Local installation does not work.

# %% [markdown]
# ## 0. Imports

# %% [markdown]
# For this laboratory you will need the following libraries:

# %%
import matplotlib.pyplot as plt
import numpy as np

import tidy3d as td

import gplugins as gp
import gplugins.tidy3d as gt
from gplugins import plot
from gplugins.common.config import PATH

nm = 1e-3
wavelength = np.linspace(1500, 1600,11) * nm
f = td.C_0 / wavelength

# %%
nitride_complex = td.material_library["Si3N4"]["Luke2015PMLStable"].eps_model(f)
nitride_index, nitride_k = td.Medium.eps_complex_to_nk(nitride_complex)
box_complex = td.material_library["SiO2"]["Horiba"].eps_model(f)
box_index, box_k = td.Medium.eps_complex_to_nk(box_complex)

#nitruro y oxido de silicio - silicon nitride

# %% [markdown]
# ## LO.1. Effective index of a waveguide
#
# ### Convergence Tests
# We have asumed until now, that the **real** value of the effective index for each cross-section is the value provided by this mode-solver. However, this number relies on a numerical method, making it sensible to some input parameters, such as the selected grid. The objective of this section is to find the dependence of the **calculated** value of the effective index with the *grid_resolution* and the *max_grid_scaling*, the two parameters that we can modify from the automatic grid function used at the gt.modes.Waveguide() function.  <br>
# - Consider a 1.2 um width deep waveguide (SiNx), with 0.3 um height operating at 1550 nm.
#     - Sweep the *grid_resolution* between 10 and 100 in steps of 10. Plot the **calculated** effective index vs the *grid_resolution*.
#     - Select a value for the *grid_resolution* from the latter sweep (where the calculated index remains almost constant), and sweep the *max_grid_scaling* from 1.2 to 1.6 in steps of 0.1. Plot the **calculated** effective index vs the *max_grid_scaling*.
#     - Conclude which will be the best configuration for the grid parameters for this particular case.

# %%
#de como configure el grid_resolution y el max_grid_scaling dependen los valores que me devuelvan

# %%
#Variamos el grid_resolution
n_eff = []

grid_values = range (10, 101, 10)


for grid in grid_values:

 deep_waveguide = gt.modes.Waveguide(
    # Geometrical Parameters
    core_width=1.2, # Waveguide width
    core_thickness=300 * nm, # Waveguide height 
    slab_thickness=0 * nm, # For shallow waveguides - Set to 0 if its a deep-etched waveguide.
    # Materials
    core_material='sin', #  Material of the waveguide
    clad_material='sio2', # Surrounding material
    # Modesolver Parameters
    wavelength=1550 * nm, # Wavelength to simulate
    num_modes=4, # Targeted number of modes to find 
    max_grid_scaling=1.5, # Parameters of the grid 
    grid_resolution=grid, # Parameters of the grid
    cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
    #siempre tener el cache activo, 
    precision='double',
 )
 n_eff.append(deep_waveguide.n_eff[0])


 print(f"  neff mode 0 = {n_eff}")
print("Sweep finished.")
deep_waveguide.plot_index()



# Student continue your code here ...
# Out:
# 2026-02-16 13:05:51.002 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_13fe960528db7e9b.npz.
#   neff mode 0 = [np.complex128(1.6292176135816765+8.87788224384938e-05j)]
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 13:05:52 CET WARNING: Mode field at frequency index 0, mode index 2 does not
#              decay at the plane boundaries.
#              WARNING: Mode field at frequency index 0, mode index 3 does not
#              decay at the plane boundaries.
# 2026-02-16 13:05:52.383 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_cf92515ae4232c65.npz.
#   neff mode 0 = [np.complex128(1.6292176135816765+8.87788224384938e-05j), np.complex128(1.6052479180535963+0.00010066149653512511j)]
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 13:05:55 CET WARNING: Mode field at frequency index 0, mode index 3 does not
#              decay at the plane boundaries.
# 2026-02-16 13:05:55.855 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_152975b7cd7bd92b.npz.
#   neff mode 0 = [np.complex128(1.6292176135816765+8.87788224384938e-05j), np.complex128(1.6052479180535963+0.00010066149653512511j), np.complex128(1.6140019734701279+9.589027705658338e-05j)]
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 13:05:59 CET WARNING: Mode field at frequency index 0, mode index 3 does not
#              decay at the plane boundaries.
# 2026-02-16 13:05:59.678 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_721700b7522a7617.npz.
#   neff mode 0 = [np.complex128(1.6292176135816765+8.87788224384938e-05j), np.complex128(1.6052479180535963+0.00010066149653512511j), np.complex128(1.6140019734701279+9.589027705658338e-05j), np.complex128(1.61159935779143+9.728993270487068e-05j)]
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 13:06:05 CET WARNING: Mode field at frequency index 0, mode index 3 does not
#              decay at the plane boundaries.
# 2026-02-16 13:06:05.815 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_0ea6c3bb3b1c00e8.npz.
#   neff mode 0 = [np.complex128(1.6292176135816765+8.87788224384938e-05j), np.complex128(1.6052479180535963+0.00010066149653512511j), np.complex128(1.6140019734701279+9.589027705658338e-05j), np.complex128(1.61159935779143+9.728993270487068e-05j), np.complex128(1.6053589955147283+0.00010054540878818744j)]
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 13:06:15 CET WARNING: Mode field at frequency index 0, mode index 3 does not
#              decay at the plane boundaries.
# 2026-02-16 13:06:15.333 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_67a04e2475ce3436.npz.
#   neff mode 0 = [np.complex128(1.6292176135816765+8.87788224384938e-05j), np.complex128(1.6052479180535963+0.00010066149653512511j), np.complex128(1.6140019734701279+9.589027705658338e-05j), np.complex128(1.61159935779143+9.728993270487068e-05j), np.complex128(1.6053589955147283+0.00010054540878818744j), np.complex128(1.6053793907406795+0.00010052243502690111j)]
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 13:06:28 CET WARNING: Mode field at frequency index 0, mode index 3 does not
#              decay at the plane boundaries.
# 2026-02-16 13:06:28.756 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_b110164ae7f9a70a.npz.
#   neff mode 0 = [np.complex128(1.6292176135816765+8.87788224384938e-05j), np.complex128(1.6052479180535963+0.00010066149653512511j), np.complex128(1.6140019734701279+9.589027705658338e-05j), np.complex128(1.61159935779143+9.728993270487068e-05j), np.complex128(1.6053589955147283+0.00010054540878818744j), np.complex128(1.6053793907406795+0.00010052243502690111j), np.complex128(1.6053907755111803+0.00010050881344795437j)]
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 13:06:45 CET WARNING: Mode field at frequency index 0, mode index 3 does not
#              decay at the plane boundaries.
# 2026-02-16 13:06:45.274 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_c8d8b6bf9be8a3e8.npz.
#   neff mode 0 = [np.complex128(1.6292176135816765+8.87788224384938e-05j), np.complex128(1.6052479180535963+0.00010066149653512511j), np.complex128(1.6140019734701279+9.589027705658338e-05j), np.complex128(1.61159935779143+9.728993270487068e-05j), np.complex128(1.6053589955147283+0.00010054540878818744j), np.complex128(1.6053793907406795+0.00010052243502690111j), np.complex128(1.6053907755111803+0.00010050881344795437j), np.complex128(1.6052625161349372+0.00010063590947997609j)]
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 13:07:07 CET WARNING: Mode field at frequency index 0, mode index 3 does not
#              decay at the plane boundaries.
# 2026-02-16 13:07:07.453 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_6ca8d26fe4d32d13.npz.
#   neff mode 0 = [np.complex128(1.6292176135816765+8.87788224384938e-05j), np.complex128(1.6052479180535963+0.00010066149653512511j), np.complex128(1.6140019734701279+9.589027705658338e-05j), np.complex128(1.61159935779143+9.728993270487068e-05j), np.complex128(1.6053589955147283+0.00010054540878818744j), np.complex128(1.6053793907406795+0.00010052243502690111j), np.complex128(1.6053907755111803+0.00010050881344795437j), np.complex128(1.6052625161349372+0.00010063590947997609j), np.complex128(1.605407520623682+0.00010048901753845174j)]
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 13:07:46 CET WARNING: Mode field at frequency index 0, mode index 3 does not
#              decay at the plane boundaries.
# 2026-02-16 13:07:46.692 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_bf9d22383e930dfa.npz.
#   neff mode 0 = [np.complex128(1.6292176135816765+8.87788224384938e-05j), np.complex128(1.6052479180535963+0.00010066149653512511j), np.complex128(1.6140019734701279+9.589027705658338e-05j), np.complex128(1.61159935779143+9.728993270487068e-05j), np.complex128(1.6053589955147283+0.00010054540878818744j), np.complex128(1.6053793907406795+0.00010052243502690111j), np.complex128(1.6053907755111803+0.00010050881344795437j), np.complex128(1.6052625161349372+0.00010063590947997609j), np.complex128(1.605407520623682+0.00010048901753845174j), np.complex128(1.605413030422194+0.00010048234928533154j)]
# Sweep finished.

# %%
plt.plot(list(grid_values), n_eff, marker='o') #ploteamos los valores respecto al incremento de grid
# Out:
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/matplotlib/cbook.py:1719: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/matplotlib/cbook.py:1355: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
#cogeremos el valor de 20 de resolution_grid que es el que ya obtiene el mejor valor con el valor resolution más pequeña

# %%
#variamos el max_grid
n_eff = []

grid_values = np.linspace(1.2, 1.6, 5)


for grid in grid_values:

 deep_waveguide = gt.modes.Waveguide(
    # Geometrical Parameters
    core_width=1.2, # Waveguide width
    core_thickness=300 * nm, # Waveguide height 
    slab_thickness=0 * nm, # For shallow waveguides - Set to 0 if its a deep-etched waveguide.
    # Materials
    core_material='sin', #  Material of the waveguide
    clad_material='sio2', # Surrounding material
    # Modesolver Parameters
    wavelength=1550 * nm, # Wavelength to simulate
    num_modes=4, # Targeted number of modes to find 
    max_grid_scaling=grid, # Parameters of the grid 
    grid_resolution=20, # Parameters of the grid
    cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
    #siempre tener el cache activo, 
    precision='double',
 )
 n_eff.append(deep_waveguide.n_eff[0])


 print(f"  neff mode 0 = {n_eff}")
print("Sweep finished.")
deep_waveguide.plot_index()
# Out:
# 2026-02-16 13:27:52.758 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_29761b037c0c9026.npz.
#   neff mode 0 = [np.complex128(1.6049334055363498+0.00010099858202903728j)]
# 2026-02-16 13:27:52.763 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_fbe312fd02002ae4.npz.
#   neff mode 0 = [np.complex128(1.6049334055363498+0.00010099858202903728j), np.complex128(1.6053726786184481+0.00010054322644637153j)]
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 13:27:53 CET WARNING: Mode field at frequency index 0, mode index 2 does not
#              decay at the plane boundaries.
#              WARNING: Mode field at frequency index 0, mode index 3 does not
#              decay at the plane boundaries.
# 2026-02-16 13:27:54.006 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_76e2764f504071ba.npz.
#   neff mode 0 = [np.complex128(1.6049334055363498+0.00010099858202903728j), np.complex128(1.6053726786184481+0.00010054322644637153j), np.complex128(1.605282619626602+0.00010062861909411382j)]
#   neff mode 0 = [np.complex128(1.6049334055363498+0.00010099858202903728j), np.complex128(1.6053726786184481+0.00010054322644637153j), np.complex128(1.605282619626602+0.00010062861909411382j), np.complex128(1.6052479180535963+0.00010066149653512511j)]
# 2026-02-16 13:27:54.014 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_cf92515ae4232c65.npz.
#   neff mode 0 = [np.complex128(1.6049334055363498+0.00010099858202903728j), np.complex128(1.6053726786184481+0.00010054322644637153j), np.complex128(1.605282619626602+0.00010062861909411382j), np.complex128(1.6052479180535963+0.00010066149653512511j), np.complex128(1.605236201827348+0.00010067619021034422j)]
# Sweep finished.
# 2026-02-16 13:27:54.016 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_683206c3f01233c4.npz.

# %%
plt.plot(list(grid_values), n_eff, marker='o') #ploteamos los valores respecto al incremento de grid
# Out:
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/matplotlib/cbook.py:1719: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/matplotlib/cbook.py:1355: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %% [markdown]
# ## LO.2. Width dependence

# %% [markdown]
# - Perform a sweep of the **deep** waveguide width. Use the code provided in the following cell or program your own sweep.

# %%
wavelength = 1550*nm # Student code here

deep_waveguide = gt.modes.Waveguide(
    wavelength=wavelength,
    core_width=1.2,
    core_material='sin',
    clad_material='sio2',
    core_thickness=300 * nm,
    slab_thickness=0 * nm,
    num_modes=4,
    cache_path='.cache/',
    precision='double',
    max_grid_scaling=1.2,
    grid_resolution=20, 
)

w = np.linspace(0.6, 1.6, 10) # Student code here

sweep_neff = gt.modes.sweep_n_eff(deep_waveguide, 
                             core_width=w)

sweep_tefraction = gt.modes.sweep_fraction_te(deep_waveguide,
                                              core_width=w)

plt.figure(figsize=(10, 5))
for k in range(sweep_neff.shape[1]):
    plt.scatter(w, sweep_neff[:,k].real,edgecolors='k',c=sweep_tefraction.sel(mode_index=k),vmin=0, vmax=1,label = '__nolegend__',cmap='bwr')
    plt.plot(w, sweep_neff[:,k].real,label=f'Mode {k}')

plt.title("Deep waveguide width sweep - 1550nm")
plt.xlabel("Width (um)")
plt.ylabel("neff")
plt.grid()
plt.hlines(np.mean(box_index), xmin=np.min(w), xmax=np.max(w), colors='k', linestyles='dashed',label='SiO2 index')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout(rect=[0, 0, 0.85, 1])
plt.colorbar(orientation='horizontal',fraction=0.04).set_label("TE fraction")
#nos apareceran los modos te en rojo y los tm en azul
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 13:35:11 CET WARNING: Mode field at frequency index 0, mode index 2 does not
#              decay at the plane boundaries.
#              WARNING: Mode field at frequency index 0, mode index 3 does not
#              decay at the plane boundaries.
# 2026-02-16 13:35:11.326 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_e0f2a62752cad497.npz.
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 13:35:12 CET WARNING: Mode field at frequency index 0, mode index 2 does not
#              decay at the plane boundaries.
#              WARNING: Mode field at frequency index 0, mode index 3 does not
#              decay at the plane boundaries.
# 2026-02-16 13:35:12.428 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_5564f2e2b0a47b2f.npz.
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 13:35:13 CET WARNING: Mode field at frequency index 0, mode index 2 does not
#              decay at the plane boundaries.
#              WARNING: Mode field at frequency index 0, mode index 3 does not
#              decay at the plane boundaries.
# 2026-02-16 13:35:13.515 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_423ace54e9018435.npz.
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 13:35:14 CET WARNING: Mode field at frequency index 0, mode index 2 does not
#              decay at the plane boundaries.
#              WARNING: Mode field at frequency index 0, mode index 3 does not
#              decay at the plane boundaries.
# 2026-02-16 13:35:14.695 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_13798a9e51464563.npz.
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 13:35:15 CET WARNING: Mode field at frequency index 0, mode index 2 does not
#              decay at the plane boundaries.
#              WARNING: Mode field at frequency index 0, mode index 3 does not
#              decay at the plane boundaries.
# 2026-02-16 13:35:15.951 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_31a376b5383f892d.npz.
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 13:35:17 CET WARNING: Mode field at frequency index 0, mode index 2 does not
#              decay at the plane boundaries.
#              WARNING: Mode field at frequency index 0, mode index 3 does not
#              decay at the plane boundaries.
# 2026-02-16 13:35:17.726 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_95b972805b4788c4.npz.
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 13:35:19 CET WARNING: Mode field at frequency index 0, mode index 3 does not
#              decay at the plane boundaries.
# 2026-02-16 13:35:19.096 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_1e23c9d166e3aaff.npz.
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 2026-02-16 13:35:20.331 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_7305bddb54556681.npz.
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 2026-02-16 13:35:21.591 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_f003a8e73ba38206.npz.
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:14: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:27: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dxb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Nx, Nx)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:42: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyf = sp.csr_matrix(sp.diags([-1, 1], [0, 1], shape=(Ny, Ny)))
# /home/rober/PRACT_1_WAVEGUIDE/pic-upv-lab1/.venv/lib/python3.12/site-packages/tidy3d/components/mode/derivatives.py:55: FutureWarning: Input has data type int64, but the output has been cast to float64.  In the future, the output data type will match the input. To avoid this warning, set the `dtype` parameter to `None` to have the output dtype match the input, or set it to the desired output data type.
#   dyb = sp.csr_matrix(sp.diags([1, -1], [0, -1], shape=(Ny, Ny)))
# 2026-02-16 13:35:22.804 | INFO     | gplugins.tidy3d.modes:_data:306 - store data into .cache/Waveguide_415c86fe948629a6.npz.
#   0%|          | 0/10 [00:00<?, ?it/s]
# 2026-02-16 13:35:22.822 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_e0f2a62752cad497.npz.
# 2026-02-16 13:35:22.825 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_5564f2e2b0a47b2f.npz.
# 2026-02-16 13:35:22.828 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_423ace54e9018435.npz.
# 2026-02-16 13:35:22.832 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_13798a9e51464563.npz.
# 2026-02-16 13:35:22.835 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_31a376b5383f892d.npz.
# 2026-02-16 13:35:22.838 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_95b972805b4788c4.npz.
# 2026-02-16 13:35:22.841 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_1e23c9d166e3aaff.npz.
# 2026-02-16 13:35:22.846 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_7305bddb54556681.npz.
# 2026-02-16 13:35:22.849 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_f003a8e73ba38206.npz.
# 2026-02-16 13:35:22.850 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_415c86fe948629a6.npz.

# %% [markdown]
# ## LO.3. Waveguide compact model

# %% [markdown]
# A compact model of an integrated photonic waveguide is a reduced-order mathematical model that describes the waveguide’s optical behavior—such as phase propagation, loss, and dispersion, using analytical or semi-analytical equations. Consider:

# %% [markdown]
# Transfer function for propagation in a waveguide:
#
# $$
# H(\lambda)
# = e^{-j\,\beta(\lambda)\,z}
# = e^{-j\,\mathrm{Re}\{\beta(\lambda)\}\,z}\,
#   e^{\mathrm{Im}\{\beta(\lambda)\}\,z}.
# $$
#
# Where
#
# $$
# \beta(\lambda)
# = \frac{2\pi}{\lambda}\,\mathrm{Re}\{n_\mathrm{eff}(\lambda)\}.
# $$
#
# Let's model the waveguide's effective index wavelength variation using a second order polynomial:
#
# $$
# n_\mathrm{eff}(\lambda)
# = n_{1} + n_{2}\,(\lambda-\lambda_{0}) + n_{3}\,(\lambda-\lambda_{0})^{2}
# $$
#
# Where
#
# 1.
# $$
# n_\mathrm{eff}(\lambda_0) = n_1
# $$
# 2.
# $$
# n_g(\lambda_0) = n_1 - n_2\,\lambda_0
# $$
# 3.
# $$
# D = -\frac{2\,\lambda_0\,n_3}{c}\;\;[\mathrm{s}^2/\mathrm{m}]
# $$
#
# - Find the **compact models** of the following waveguides:
#     - Deep waveguide, height = 300nm, width = 1.2um
#     - Shallow waveguide, core height = 300nm, slab height = 150 nm, width = 1.2um
#
# **TIP**. Use the Lab0.1.Modesolver results (neff vs lambda) as starting point. Fit the results using a second order polynomial (with the lambda_0 shift) and relate the fit results to n_g and D values.

# %%
# STUDENT! Put your code here.
#Neff lambda está en el laboratorio anterior que es diferente para la guia deep y la guia shallow.
#Indice efectivo te para la deep, el del te, y lo mismo para la shallow. 
#cuadndo queremos el polinomio de segundo orden cogemos el vector y hacemos un polifit de segundo orden
#sacaremos despues con n1 y n2 el indice de grupo, y con n3 la dispersion
#un índice muy grande indicaria mucha variabilidad de longitud de onda.
#los modelos compactos son neff, ng y D 
#los valores del indice de grupo deben ser cercanos a los 2 te, 1.5 tm,en la deep
#para la guia shallow del orden de 1,7

# %% [markdown]
# ## LO.4. Bend waveguide radius vs. loss – deep

# %% [markdown]
# The bend loss has three primary contributions:
#
# 1. Mode-mismatch loss
# 2. Radiation loss
# 3. Propagation loss

# %%
bend_1550 = gt.modes.Waveguide(
    wavelength=1550 * nm,
    core_width=1.2,
    slab_thickness=0.0,
    core_material='sin',
    clad_material='sio2',
    core_thickness=300 * nm,
    num_modes=1,
    cache_path='.cache/',
    precision='double',
    max_grid_scaling=1.2,
    grid_resolution=30, 
    bend_radius=20, # Bend radius
)

bend_1550.plot_field(field_name="Ex", 
                     mode_index=0, # Field to be plotted
                     value='real', # Real - abs - imag
                     cmap='coolwarm',
                     xlim=(-1.5, 1.5), # Set the x and y limits
                     ylim=(-0.7, 1))

# %% [markdown]
# ### Mode-mismatch loss
#
# Bend waveguide mode differs slightly from the straight waveguide mode, wich yield into mode-convertion losses. We can calculate this factor with as the overlap of the latter two modes.
#
# This is already implemented on GDSfactory library:

# %%
radii = np.arange(20.0, 120,11)

mismatch = gt.modes.sweep_bend_mismatch(bend_1550, radii)

plt.plot(radii, 10 * np.log10(mismatch))
plt.title("Strip waveguide bend")
plt.xlabel("Radius (μm)")
plt.ylabel("Mismatch (dB)")

# %% [markdown]
# ### Propagation loss
#
# Consider the equivalent linear length of the quarter-circle bend. Light will attenuate following a trend quantified with the experimentally measured parameter $$\alpha [\mathrm{dB}/\mathrm{cm}]$$. It depends on the fabrication process mainly. We will add this loss (in dBs) to the mode-mismatch loss to calculate the total loss per bend.
#
# *We are not considering the radiation losses, mainly because is not easy to implement a quick simulation for this parameter. Under certain conditions, the main loss sources are the ones considered in this example

# %%
dB_cm = 1.5  # dB/cm Technology loss - 
length = 0.5 * np.pi * radii * 1e-6
propagation_loss = dB_cm * length * 1e2
propagation_loss

plt.title("Bend loss for TE polarization")
plt.plot(radii, -10 * np.log10(mismatch), ".", label="Mode loss")
plt.plot(radii, propagation_loss, ".", label="Propagation loss")
plt.plot(radii, propagation_loss-10 * np.log10(mismatch), ".", label="Total loss")
plt.xlabel("Bend radius (um)")
plt.ylabel("Loss (dB)")
plt.legend()

# %% [markdown]
# - Use the code provided in this section to calculate the safe radius for 1.2 um width deep waveguides at 1.5 um.

# %% [markdown]
# ## EXTRA
#
# All the past simulations were done considering as core material de Silicon Nitride (SiNx) and Silicon Dioxide (SiO2) as cladding material. Now, **simulate the Silicon-On-Insulator technology changing the core material to Silicon (Si)**. In this case, the dimensions will be 220 nm heigth and 500 nm width.
# 1. Repeat the LO.1. wavelength behavior simulations, considering the updated materials and dimensions.
# 2. Repeat the LO.3. width dependence analysis, now sweeping in a 300nm - 1um range.
# 3. Find the safe radius for this technology. Consider sweeping the radius in a 5um to 30um range.
# 4. **Compare the SiNx and SOI technologies**

# %% [markdown]
# ## Grading
#
# LO.1. 2 Point <br>
# LO.2. 1 Points <br>
# LO.3. 3 Point <br>
# LO.4. 1 Points <br>
# **Total 7 Points** <br>
# Extra (Up to) 3 Points
